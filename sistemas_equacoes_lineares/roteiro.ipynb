# %%
import numpy as np
import scipy.linalg as sla

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

# %%
np.c_[a,b]
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
c = np.array([7,8,9]).reshape(1,3)

# %%
print('a: ',a.shape)
print('c: ',c.shape)
# Out:
# a:  (3,)
# c:  (1, 3)

# %%
np.c_[a,c]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 np.c_[a,c]
#
# File c:\Repository\Metodos_Numericos\.venv\Lib\site-packages\numpy\lib\_index_tricks_impl.py:435, in AxisConcatenator.__getitem__(self, key)
#     431     # concatenate could do cast, but that can be overridden:
#     432     objs = [array(obj, copy=None, subok=True,
#     433                   ndmin=ndmin, dtype=final_dtype) for obj in objs]
# --> 435 res = self.concatenate(tuple(objs), axis=axis)
#     437 if matrix:
#     438     oldndim = res.ndim
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 3 and the array at index 1 has size 1

# %%
A = np.array([[2,3,5],[1,-1,10],[-1,1,-1]])

b = np.array([10,20,5])

# %%
np.linalg.matrix_rank(A)
# Out:
# np.int64(3)

# %%
np.linalg.matrix_rank(np.c_[A, b])
# Out:
# np.int64(3)

# %%
A.shape[1]
# Out:
# 3

# %%
def sist_lin_diagonal(A,b): return b/A.diagonal()

# %%
A = np.diag([1,4,2])
b = np.array([4, 2, 2])

# %%
sist_lin_diagonal(A,b)
# Out:
# array([4. , 0.5, 1. ])

# %%
np.empty(3).shape
# Out:
# (3,)

# %%
np.array([]).shape
# Out:
# (0,)

# %%
def sist_lin_tri_sup(A,b):
    n = len(b)
    x = np.empty(n)
    x[-1] = b[-1]/A[-1, -1]
    for i in range(n-2, -1, -1):
        x[i] = (b[i] - np.sum(A[i,i+1:]*x[i+1:]))/A[i,i]
    return x

# %%
A = np.array([[3,4,-5,1],[0,1,1,-2],[0,0,4,-5],[0,0,0,2]])

b = np.array([-10,-1,3,2])

# %%
x = sist_lin_tri_sup(A,b)

x
# Out:
# array([ 1., -1.,  2.,  1.])

# %%
A.dot(x)
# Out:
# array([-10.,  -1.,   3.,   2.])

# %%
def sist_lin_tri_inf(A,b):
    n = len(b)
    x = np.empty(n)
    x[0] = b[0]/A[0, 0]
    for i in range(1,n):
        x[i] = (b[i] - np.sum(A[i,:i]*x[:i]))/A[i,i]
    return x

# %%
A = np.array([[3,0,0,0],[2,1,0,0],[1,0,1,0],[1,1,1,1]])

b = np.array([4,2,4,2])

# %%
x = sist_lin_tri_inf(A,b)

x
# Out:
# array([ 1.33333333, -0.66666667,  2.66666667, -1.33333333])

# %%
A.dot(x)
# Out:
# array([4., 2., 4., 2.])

# %%
A1 = np.array([[3,4,-5,1],[0,1,1,-2],[0,0,4,-5],[0,0,0,2]])

b1 = np.array([-10,-1,3,2])

# %%
sla.solve_triangular(A1,b1, lower=False)
# Out:
# array([ 1., -1.,  2.,  1.])

# %%
A2 = np.array([[3,0,0,0],[2,1,0,0],[1,0,1,0],[1,1,1,1]])

b2 = np.array([4,2,4,2])

# %%
sla.solve_triangular(A2,b2, lower=True)
# Out:
# array([ 1.33333333, -0.66666667,  2.66666667, -1.33333333])
